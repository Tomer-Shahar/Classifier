# %% [markdown]
# # Document Classification Assignment

# %% [markdown]
# This assignment consists of two parts, the first being a document pre-processor class that collects data from a given corpus and also cleans the data. The second part is a document classifier, classifying a given test set into one/multiple types out of 23 possible options.

# %% [markdown]
# ## Submitted by: Shakey Eyal 201605870 && Tomer Shahar 302223979

# %% [markdown]
# ## Part 1:

# %%
The main function. Here you can set the location of the corpus folder. You can also set the location of the output folder.
The PreProcessor object will process the files in the given path. Note that it will first process the TRAINING set and only then
the TEST set.

# %%
from preprocessor import PreProcessor

corpus_path = 'D:\\ohsumed-first-20000-docs'  # PATH TO THE CORPUS FOLDER THAT CONTAINS THE SUB-FOLDERS
output_path = 'D:\\parsed_files'  # Output path where the statistics and parsed files will be saved

prep = PreProcessor(corpus_path, output_path)
prep.process_all_files()
# Out:
# Number of categories: 23
# Number of documents per category:
# 1. Bacterial Infections and Mycoses: 423
# 2. Virus Diseases: 158
# 3. Parasitic Diseases: 65
# 4. Neoplasms: 1163
# 5. Musculoskeletal Diseases: 283
# 6. Digestive System Diseases: 588
# 7. Stomatognathic Diseases: 100
# 8. Respiratory Tract Diseases: 473
# 9. Otorhinolaryngologic Diseases: 125
# 10. Nervous System Diseases: 621
# 11. Eye Diseases: 162
# 12. Urologic and Male Genital Diseases: 491
# 13. Female Genital Diseases and Pregnancy Complications: 281
# 14. Cardiovascular Diseases: 1249
# 15. Hemic and Lymphatic Diseases: 215
# 16. Neonatal Diseases and Abnormalities: 200
# 17. Skin and Connective Tissue Diseases: 295
# 18. Nutritional and Metabolic Diseases: 388
# 19. Endocrine Diseases: 191
# 20. Immunologic Diseases: 525
# 21. Disorders of Environmental Origin: 546
# 22. Animal Diseases: 92
# 23. Pathological Conditions, Signs and Symptoms: 1799
#
# Top 10 Words Per Category:
#
# Bacterial Infections and Mycoses:
# 1. 'patient' appeared 973 times
# 2. 'infect' appeared 633 times
# 3. 'treatment' appeared 265 times
# 4. 'group' appeared 257 times
# 5. 'case' appeared 243 times
# 6. 'diseas' appeared 240 times
# 7. 'use' appeared 210 times
# 8. 'studi' appeared 198 times
# 9. 'clinic' appeared 192 times
# 10. 'therapi' appeared 178 times
#
# Virus Diseases:
# 1. 'patient' appeared 286 times
# 2. 'infect' appeared 274 times
# 3. 'virus' appeared 195 times
# 4. 'human' appeared 139 times
# 5. 'cell' appeared 113 times
# 6. 'immunodefici' appeared 101 times
# 7. 'diseas' appeared 98 times
# 8. 'studi' appeared 88 times
# 9. 'hiv' appeared 87 times
# 10. 'case' appeared 83 times
#
# Parasitic Diseases:
# 1. 'patient' appeared 111 times
# 2. 'infect' appeared 92 times
# 3. 'diseas' appeared 46 times
# 4. 'parasit' appeared 44 times
# 5. 'studi' appeared 43 times
# 6. 'case' appeared 42 times
# 7. 'day' appeared 33 times
# 8. 'treatment' appeared 33 times
# 9. 'antibodi' appeared 31 times
# 10. 'control' appeared 28 times
#
# Neoplasms:
# 1. 'patient' appeared 2882 times
# 2. 'cell' appeared 1612 times
# 3. 'tumor' appeared 1445 times
# 4. 'cancer' appeared 1000 times
# 5. 'carcinoma' appeared 902 times
# 6. 'case' appeared 700 times
# 7. 'studi' appeared 695 times
# 8. 'use' appeared 619 times
# 9. 'treatment' appeared 566 times
# 10. 'diseas' appeared 549 times
#
# Musculoskeletal Diseases:
# 1. 'patient' appeared 584 times
# 2. 'bone' appeared 214 times
# 3. 'studi' appeared 158 times
# 4. 'use' appeared 146 times
# 5. 'result' appeared 136 times
# 6. 'case' appeared 127 times
# 7. 'group' appeared 119 times
# 8. 'year' appeared 115 times
# 9. 'treatment' appeared 113 times
# 10. 'knee' appeared 112 times
#
# Digestive System Diseases:
# 1. 'patient' appeared 1883 times
# 2. 'diseas' appeared 538 times
# 3. 'studi' appeared 404 times
# 4. 'group' appeared 322 times
# 5. 'signific' appeared 321 times
# 6. 'less' appeared 313 times
# 7. 'p' appeared 296 times
# 8. 'use' appeared 277 times
# 9. 'treatment' appeared 276 times
# 10. 'gastric' appeared 260 times
#
# Stomatognathic Diseases:
# 1. 'patient' appeared 151 times
# 2. 'cell' appeared 63 times
# 3. 'periodont' appeared 59 times
# 4. 'treatment' appeared 57 times
# 5. 'case' appeared 55 times
# 6. 'use' appeared 47 times
# 7. 'tumor' appeared 47 times
# 8. 'diseas' appeared 43 times
# 9. 'gland' appeared 40 times
# 10. 'studi' appeared 40 times
#
# Respiratory Tract Diseases:
# 1. 'patient' appeared 1171 times
# 2. 'lung' appeared 465 times
# 3. 'pulmonari' appeared 420 times
# 4. 'group' appeared 314 times
# 5. 'studi' appeared 297 times
# 6. 'diseas' appeared 289 times
# 7. 'p' appeared 275 times
# 8. 'less' appeared 264 times
# 9. 'use' appeared 250 times
# 10. 'increas' appeared 250 times
#
# Otorhinolaryngologic Diseases:
# 1. 'patient' appeared 229 times
# 2. 'ear' appeared 81 times
# 3. 'use' appeared 75 times
# 4. 'case' appeared 69 times
# 5. 'studi' appeared 65 times
# 6. 'group' appeared 64 times
# 7. 'diseas' appeared 61 times
# 8. 'signific' appeared 57 times
# 9. 'treatment' appeared 56 times
# 10. 'nasal' appeared 54 times
#
# Nervous System Diseases:
# 1. 'patient' appeared 1529 times
# 2. 'studi' appeared 396 times
# 3. 'group' appeared 371 times
# 4. 'use' appeared 324 times
# 5. 'signific' appeared 272 times
# 6. 'pain' appeared 270 times
# 7. 'diseas' appeared 264 times
# 8. 'result' appeared 247 times
# 9. 'clinic' appeared 245 times
# 10. 'case' appeared 243 times
#
# Eye Diseases:
# 1. 'patient' appeared 314 times
# 2. 'eye' appeared 176 times
# 3. 'retin' appeared 132 times
# 4. 'use' appeared 87 times
# 5. 'case' appeared 79 times
# 6. 'diseas' appeared 74 times
# 7. 'visual' appeared 73 times
# 8. 'studi' appeared 73 times
# 9. 'develop' appeared 63 times
# 10. 'group' appeared 62 times
#
# Urologic and Male Genital Diseases:
# 1. 'patient' appeared 1315 times
# 2. 'renal' appeared 569 times
# 3. 'studi' appeared 304 times
# 4. 'treatment' appeared 303 times
# 5. 'prostat' appeared 302 times
# 6. 'use' appeared 268 times
# 7. 'signific' appeared 260 times
# 8. 'diseas' appeared 259 times
# 9. 'cell' appeared 254 times
# 10. 'tumor' appeared 254 times
#
# Female Genital Diseases and Pregnancy Complications:
# 1. 'patient' appeared 410 times
# 2. 'pregnanc' appeared 321 times
# 3. 'women' appeared 316 times
# 4. 'infect' appeared 176 times
# 5. 'use' appeared 171 times
# 6. 'group' appeared 167 times
# 7. 'studi' appeared 147 times
# 8. 'signific' appeared 130 times
# 9. 'diseas' appeared 119 times
# 10. 'treatment' appeared 118 times
#
# Cardiovascular Diseases:
# 1. 'patient' appeared 3828 times
# 2. 'arteri' appeared 1272 times
# 3. 'group' appeared 1096 times
# 4. 'coronari' appeared 1053 times
# 5. 'less' appeared 1039 times
# 6. 'p' appeared 1001 times
# 7. 'ventricular' appeared 897 times
# 8. 'heart' appeared 874 times
# 9. 'studi' appeared 874 times
# 10. 'signific' appeared 842 times
#
# Hemic and Lymphatic Diseases:
# 1. 'patient' appeared 608 times
# 2. 'cell' appeared 242 times
# 3. 'diseas' appeared 161 times
# 4. 'studi' appeared 129 times
# 5. 'case' appeared 127 times
# 6. 'increas' appeared 113 times
# 7. 'syndrom' appeared 110 times
# 8. 'group' appeared 107 times
# 9. 'p' appeared 103 times
# 10. 'less' appeared 94 times
#
# Neonatal Diseases and Abnormalities:
# 1. 'patient' appeared 467 times
# 2. 'group' appeared 142 times
# 3. 'studi' appeared 141 times
# 4. 'infant' appeared 134 times
# 5. 'arteri' appeared 133 times
# 6. 'ventricular' appeared 119 times
# 7. 'pulmonari' appeared 110 times
# 8. 'use' appeared 107 times
# 9. 'defect' appeared 105 times
# 10. 'age' appeared 101 times
#
# Skin and Connective Tissue Diseases:
# 1. 'patient' appeared 615 times
# 2. 'cell' appeared 242 times
# 3. 'diseas' appeared 222 times
# 4. 'skin' appeared 218 times
# 5. 'studi' appeared 168 times
# 6. 'lesion' appeared 151 times
# 7. 'use' appeared 137 times
# 8. 'treatment' appeared 137 times
# 9. 'case' appeared 121 times
# 10. 'may' appeared 116 times
#
# Nutritional and Metabolic Diseases:
# 1. 'patient' appeared 739 times
# 2. 'diabet' appeared 716 times
# 3. 'glucos' appeared 405 times
# 4. 'insulin' appeared 398 times
# 5. 'studi' appeared 328 times
# 6. 'level' appeared 327 times
# 7. 'increas' appeared 322 times
# 8. 'less' appeared 309 times
# 9. 'control' appeared 294 times
# 10. 'p' appeared 291 times
#
# Endocrine Diseases:
# 1. 'patient' appeared 567 times
# 2. 'diabet' appeared 264 times
# 3. 'level' appeared 155 times
# 4. 'thyroid' appeared 148 times
# 5. 'studi' appeared 146 times
# 6. 'less' appeared 146 times
# 7. 'glucos' appeared 135 times
# 8. 'signific' appeared 125 times
# 9. 'diseas' appeared 123 times
# 10. 'p' appeared 119 times
#
# Immunologic Diseases:
# 1. 'patient' appeared 1274 times
# 2. 'infect' appeared 600 times
# 3. 'cell' appeared 552 times
# 4. 'diseas' appeared 387 times
# 5. 'hiv' appeared 356 times
# 6. 'studi' appeared 345 times
# 7. 'human' appeared 328 times
# 8. 'use' appeared 309 times
# 9. 'immunodefici' appeared 307 times
# 10. 'virus' appeared 288 times
#
# Disorders of Environmental Origin:
# 1. 'patient' appeared 1080 times
# 2. 'injuri' appeared 589 times
# 3. 'use' appeared 375 times
# 4. 'alcohol' appeared 351 times
# 5. 'studi' appeared 330 times
# 6. 'result' appeared 261 times
# 7. 'fractur' appeared 245 times
# 8. 'case' appeared 242 times
# 9. 'signific' appeared 220 times
# 10. 'effect' appeared 220 times
#
# Animal Diseases:
# 1. 'model' appeared 115 times
# 2. 'rat' appeared 114 times
# 3. 'studi' appeared 99 times
# 4. 'anim' appeared 96 times
# 5. 'group' appeared 80 times
# 6. 'effect' appeared 78 times
# 7. 'human' appeared 68 times
# 8. 'infect' appeared 68 times
# 9. 'increas' appeared 66 times
# 10. 'signific' appeared 64 times
#
# Pathological Conditions, Signs and Symptoms:
# 1. 'patient' appeared 4876 times
# 2. 'group' appeared 1207 times
# 3. 'studi' appeared 1042 times
# 4. 'use' appeared 1019 times
# 5. 'less' appeared 861 times
# 6. 'case' appeared 829 times
# 7. 'signific' appeared 824 times
# 8. 'diseas' appeared 786 times
# 9. 'p' appeared 772 times
# 10. 'result' appeared 771 times

# %% [markdown]
# It is also possible to just load the statistics by reading from the existing statistics file:
# (Note that all histograms are already saved in the histogram folder)

# %%
prep.load_statistics('D:\\parsed_files\\statistics')
prep.print_statistics()
# Out:
# Number of categories: 23
# Number of documents per category:
# 1. Bacterial Infections and Mycoses: 423
# 2. Virus Diseases: 158
# 3. Parasitic Diseases: 65
# 4. Neoplasms: 1163
# 5. Musculoskeletal Diseases: 283
# 6. Digestive System Diseases: 588
# 7. Stomatognathic Diseases: 100
# 8. Respiratory Tract Diseases: 473
# 9. Otorhinolaryngologic Diseases: 125
# 10. Nervous System Diseases: 621
# 11. Eye Diseases: 162
# 12. Urologic and Male Genital Diseases: 491
# 13. Female Genital Diseases and Pregnancy Complications: 281
# 14. Cardiovascular Diseases: 1249
# 15. Hemic and Lymphatic Diseases: 215
# 16. Neonatal Diseases and Abnormalities: 200
# 17. Skin and Connective Tissue Diseases: 295
# 18. Nutritional and Metabolic Diseases: 388
# 19. Endocrine Diseases: 191
# 20. Immunologic Diseases: 525
# 21. Disorders of Environmental Origin: 546
# 22. Animal Diseases: 92
# 23. Pathological Conditions, Signs and Symptoms: 1799
#
# Top 10 Words Per Category:
#
# Bacterial Infections and Mycoses:
# 1. 'patient' appeared 973 times
# 2. 'infect' appeared 633 times
# 3. 'treatment' appeared 265 times
# 4. 'group' appeared 257 times
# 5. 'case' appeared 243 times
# 6. 'diseas' appeared 240 times
# 7. 'use' appeared 210 times
# 8. 'studi' appeared 198 times
# 9. 'clinic' appeared 192 times
# 10. 'therapi' appeared 178 times
#
# Virus Diseases:
# 1. 'patient' appeared 286 times
# 2. 'infect' appeared 274 times
# 3. 'virus' appeared 195 times
# 4. 'human' appeared 139 times
# 5. 'cell' appeared 113 times
# 6. 'immunodefici' appeared 101 times
# 7. 'diseas' appeared 98 times
# 8. 'studi' appeared 88 times
# 9. 'hiv' appeared 87 times
# 10. 'case' appeared 83 times
#
# Parasitic Diseases:
# 1. 'patient' appeared 111 times
# 2. 'infect' appeared 92 times
# 3. 'diseas' appeared 46 times
# 4. 'parasit' appeared 44 times
# 5. 'studi' appeared 43 times
# 6. 'case' appeared 42 times
# 7. 'day' appeared 33 times
# 8. 'treatment' appeared 33 times
# 9. 'antibodi' appeared 31 times
# 10. 'control' appeared 28 times
#
# Neoplasms:
# 1. 'patient' appeared 2882 times
# 2. 'cell' appeared 1612 times
# 3. 'tumor' appeared 1445 times
# 4. 'cancer' appeared 1000 times
# 5. 'carcinoma' appeared 902 times
# 6. 'case' appeared 700 times
# 7. 'studi' appeared 695 times
# 8. 'use' appeared 619 times
# 9. 'treatment' appeared 566 times
# 10. 'diseas' appeared 549 times
#
# Musculoskeletal Diseases:
# 1. 'patient' appeared 584 times
# 2. 'bone' appeared 214 times
# 3. 'studi' appeared 158 times
# 4. 'use' appeared 146 times
# 5. 'result' appeared 136 times
# 6. 'case' appeared 127 times
# 7. 'group' appeared 119 times
# 8. 'year' appeared 115 times
# 9. 'treatment' appeared 113 times
# 10. 'knee' appeared 112 times
#
# Digestive System Diseases:
# 1. 'patient' appeared 1883 times
# 2. 'diseas' appeared 538 times
# 3. 'studi' appeared 404 times
# 4. 'group' appeared 322 times
# 5. 'signific' appeared 321 times
# 6. 'less' appeared 313 times
# 7. 'p' appeared 296 times
# 8. 'use' appeared 277 times
# 9. 'treatment' appeared 276 times
# 10. 'gastric' appeared 260 times
#
# Stomatognathic Diseases:
# 1. 'patient' appeared 151 times
# 2. 'cell' appeared 63 times
# 3. 'periodont' appeared 59 times
# 4. 'treatment' appeared 57 times
# 5. 'case' appeared 55 times
# 6. 'use' appeared 47 times
# 7. 'tumor' appeared 47 times
# 8. 'diseas' appeared 43 times
# 9. 'gland' appeared 40 times
# 10. 'studi' appeared 40 times
#
# Respiratory Tract Diseases:
# 1. 'patient' appeared 1171 times
# 2. 'lung' appeared 465 times
# 3. 'pulmonari' appeared 420 times
# 4. 'group' appeared 314 times
# 5. 'studi' appeared 297 times
# 6. 'diseas' appeared 289 times
# 7. 'p' appeared 275 times
# 8. 'less' appeared 264 times
# 9. 'use' appeared 250 times
# 10. 'increas' appeared 250 times
#
# Otorhinolaryngologic Diseases:
# 1. 'patient' appeared 229 times
# 2. 'ear' appeared 81 times
# 3. 'use' appeared 75 times
# 4. 'case' appeared 69 times
# 5. 'studi' appeared 65 times
# 6. 'group' appeared 64 times
# 7. 'diseas' appeared 61 times
# 8. 'signific' appeared 57 times
# 9. 'treatment' appeared 56 times
# 10. 'nasal' appeared 54 times
#
# Nervous System Diseases:
# 1. 'patient' appeared 1529 times
# 2. 'studi' appeared 396 times
# 3. 'group' appeared 371 times
# 4. 'use' appeared 324 times
# 5. 'signific' appeared 272 times
# 6. 'pain' appeared 270 times
# 7. 'diseas' appeared 264 times
# 8. 'result' appeared 247 times
# 9. 'clinic' appeared 245 times
# 10. 'case' appeared 243 times
#
# Eye Diseases:
# 1. 'patient' appeared 314 times
# 2. 'eye' appeared 176 times
# 3. 'retin' appeared 132 times
# 4. 'use' appeared 87 times
# 5. 'case' appeared 79 times
# 6. 'diseas' appeared 74 times
# 7. 'visual' appeared 73 times
# 8. 'studi' appeared 73 times
# 9. 'develop' appeared 63 times
# 10. 'group' appeared 62 times
#
# Urologic and Male Genital Diseases:
# 1. 'patient' appeared 1315 times
# 2. 'renal' appeared 569 times
# 3. 'studi' appeared 304 times
# 4. 'treatment' appeared 303 times
# 5. 'prostat' appeared 302 times
# 6. 'use' appeared 268 times
# 7. 'signific' appeared 260 times
# 8. 'diseas' appeared 259 times
# 9. 'cell' appeared 254 times
# 10. 'tumor' appeared 254 times
#
# Female Genital Diseases and Pregnancy Complications:
# 1. 'patient' appeared 410 times
# 2. 'pregnanc' appeared 321 times
# 3. 'women' appeared 316 times
# 4. 'infect' appeared 176 times
# 5. 'use' appeared 171 times
# 6. 'group' appeared 167 times
# 7. 'studi' appeared 147 times
# 8. 'signific' appeared 130 times
# 9. 'diseas' appeared 119 times
# 10. 'treatment' appeared 118 times
#
# Cardiovascular Diseases:
# 1. 'patient' appeared 3828 times
# 2. 'arteri' appeared 1272 times
# 3. 'group' appeared 1096 times
# 4. 'coronari' appeared 1053 times
# 5. 'less' appeared 1039 times
# 6. 'p' appeared 1001 times
# 7. 'ventricular' appeared 897 times
# 8. 'heart' appeared 874 times
# 9. 'studi' appeared 874 times
# 10. 'signific' appeared 842 times
#
# Hemic and Lymphatic Diseases:
# 1. 'patient' appeared 608 times
# 2. 'cell' appeared 242 times
# 3. 'diseas' appeared 161 times
# 4. 'studi' appeared 129 times
# 5. 'case' appeared 127 times
# 6. 'increas' appeared 113 times
# 7. 'syndrom' appeared 110 times
# 8. 'group' appeared 107 times
# 9. 'p' appeared 103 times
# 10. 'less' appeared 94 times
#
# Neonatal Diseases and Abnormalities:
# 1. 'patient' appeared 467 times
# 2. 'group' appeared 142 times
# 3. 'studi' appeared 141 times
# 4. 'infant' appeared 134 times
# 5. 'arteri' appeared 133 times
# 6. 'ventricular' appeared 119 times
# 7. 'pulmonari' appeared 110 times
# 8. 'use' appeared 107 times
# 9. 'defect' appeared 105 times
# 10. 'age' appeared 101 times
#
# Skin and Connective Tissue Diseases:
# 1. 'patient' appeared 615 times
# 2. 'cell' appeared 242 times
# 3. 'diseas' appeared 222 times
# 4. 'skin' appeared 218 times
# 5. 'studi' appeared 168 times
# 6. 'lesion' appeared 151 times
# 7. 'use' appeared 137 times
# 8. 'treatment' appeared 137 times
# 9. 'case' appeared 121 times
# 10. 'may' appeared 116 times
#
# Nutritional and Metabolic Diseases:
# 1. 'patient' appeared 739 times
# 2. 'diabet' appeared 716 times
# 3. 'glucos' appeared 405 times
# 4. 'insulin' appeared 398 times
# 5. 'studi' appeared 328 times
# 6. 'level' appeared 327 times
# 7. 'increas' appeared 322 times
# 8. 'less' appeared 309 times
# 9. 'control' appeared 294 times
# 10. 'p' appeared 291 times
#
# Endocrine Diseases:
# 1. 'patient' appeared 567 times
# 2. 'diabet' appeared 264 times
# 3. 'level' appeared 155 times
# 4. 'thyroid' appeared 148 times
# 5. 'studi' appeared 146 times
# 6. 'less' appeared 146 times
# 7. 'glucos' appeared 135 times
# 8. 'signific' appeared 125 times
# 9. 'diseas' appeared 123 times
# 10. 'p' appeared 119 times
#
# Immunologic Diseases:
# 1. 'patient' appeared 1274 times
# 2. 'infect' appeared 600 times
# 3. 'cell' appeared 552 times
# 4. 'diseas' appeared 387 times
# 5. 'hiv' appeared 356 times
# 6. 'studi' appeared 345 times
# 7. 'human' appeared 328 times
# 8. 'use' appeared 309 times
# 9. 'immunodefici' appeared 307 times
# 10. 'virus' appeared 288 times
#
# Disorders of Environmental Origin:
# 1. 'patient' appeared 1080 times
# 2. 'injuri' appeared 589 times
# 3. 'use' appeared 375 times
# 4. 'alcohol' appeared 351 times
# 5. 'studi' appeared 330 times
# 6. 'result' appeared 261 times
# 7. 'fractur' appeared 245 times
# 8. 'case' appeared 242 times
# 9. 'signific' appeared 220 times
# 10. 'effect' appeared 220 times
#
# Animal Diseases:
# 1. 'model' appeared 115 times
# 2. 'rat' appeared 114 times
# 3. 'studi' appeared 99 times
# 4. 'anim' appeared 96 times
# 5. 'group' appeared 80 times
# 6. 'effect' appeared 78 times
# 7. 'human' appeared 68 times
# 8. 'infect' appeared 68 times
# 9. 'increas' appeared 66 times
# 10. 'signific' appeared 64 times
#
# Pathological Conditions, Signs and Symptoms:
# 1. 'patient' appeared 4876 times
# 2. 'group' appeared 1207 times
# 3. 'studi' appeared 1042 times
# 4. 'use' appeared 1019 times
# 5. 'less' appeared 861 times
# 6. 'case' appeared 829 times
# 7. 'signific' appeared 824 times
# 8. 'diseas' appeared 786 times
# 9. 'p' appeared 772 times
# 10. 'result' appeared 771 times

# %% [markdown]
# ## Task Challenges:
# # Here we're describing why this is difficult.

# %% [markdown]
# ## Part 2:
